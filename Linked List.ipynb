# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printLL(head):
    while head is not None:
        print(head.data , end = ' ')
        head = head.next
    print("None")
    return

def length(head):
    n = 0
    while head is not None:
        n += 1
        head = head.next
    return n

def insertAtIR(head,i,data):
    if i<0:
        return head
    if i==0:
        newNode=Node(data)
        newNode.next=head
        return newNode
    if head is None:
        return None
    smallHead=insertAtIR(head.next,i-1,data)
    head.next=smallHead
    return head


def insertAtI(head,i,data):
    if i<0 or i>length(head):
        return head
    count=0
    prev=None
    curr=head
    while count<i:
        
        
        prev=curr
        curr=curr.next
        count=count+1
    newNode=Node(data)
    if prev is not None:
        prev.next=newNode
    else:
        head=newNode
    
    newNode.next=curr
    return head

def deleteNode(head,p):
    if head is None:
        return head
    if p == 0:
        return head.next
    count = 0
    cur = head
    while cur is not None and count < p:
        count += 1
        cur = cur.next
    if cur is None or cur.next is None:
        return head
    cur.next = cur.next.next
    return head

def deleteNodeRec(head, pos) :
	#Your code goes here
    if pos < 0:
        return head
    if pos == 0:
        return head.next
    if head.next is None:
        return head
    smallerHead = deleteNodeRec(head.next,pos-1)
    head.next = smallerHead
    return head

def reverseLinkedListRec(head) :
	#Your code goes here
    if head is None:
        return None
    if head.next is None:
        return head
    tail = head.next
    smallerHead = reverseLinkedListRec(head.next)
    tail.next = head
    head.next = None
    return smallerHead

def reverseLLI(head):
    printLL(head)
    curr = head
    prev = None
    while curr is not None:
        nxt = curr.next
        curr.next = prev
        prev = curr
        curr = nxt
    return prev
    
    
    
    
    
    
    
def insertInLL(head,i,num):
    if i<0 or i>length(head):
        return head
    
    count = 0
    prev = None
    curr = head
    while count<i:
        prev = curr
        curr = curr.next
        count += 1
    newN = Node(num)
    if prev is not None:
        prev.next = newN
    else:
        head = newN
    newN.next = curr
    
    return head

def merge2LL(head1,head2):
    fh = None
    ft = None
    while (head1 != None and head2 != None):
        if head1.data < head2.data:
            fh = head1
            ft.next = head1
            ft = ft.next
            head1 = head1.next
        else:
            fh = head2
            ft.next = head2
            ft = ft.next
            head2.next
    if head1 != None:
        ft.next = head1
    else:
        ft.next = head2
        


        
def takeInput():
    inputArr = [int(x) for x in input().split()]
    head = None
    tail = None
    for ele in inputArr:
        if ele == -1:
            break
        newNode = Node(ele)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

head = takeInput()
hed = reverseLLI(head)
printLL(hed)
# Out:
# 1 2 3 4
# 1 2 3 4 None
# 4 3 2 1 None

# %%
from math import *
from collections import *
from sys import *
from os import *

## Read input as specified in the question.
## Print output as specified in the question.
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def divideLL(head):
    print(head.next.data)
    





def takeInput(arr):
    head = None
    tail = None
    for i in range(len(arr)):
        if arr[i] != -1:
            data = arr[i]
            newNode = Node(data)
            if head is None:
                head = newNode
                tail = newNode
            else:
                tail.next = newNode
                tail = newNode

    return head






arr = [int(i) for i in input().strip().split()]
head = takeInput(arr)
divideLL(head)
# Out:
# 1 2 3 4 5 -1
# 2
